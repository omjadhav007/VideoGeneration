# %%
from TTS.api import TTS
import os

# %%
def generate_voice(script, output_audio_path):
    # Using Tacotron 2 for TTS
    tts = TTS(model_name="tts_models/en/ljspeech/tacotron2-DDC")
    alignment_data = tts.tts(text=script, file_path=output_audio_path, speaker_wav=None, return_raw_alignments=True)
    return alignment_data

# %%
audio_path = "Strengths-of-Agile.wav"
script1='Highly adaptable to evolving requirements, design changes, and scope modifications.'
script='''
Raj had always been curious about the National Cadet Corps (NCC), but when he joined, he never imagined it would involve guns. The day they arrived at the training camp, he felt both excited and nervous.
"Today, you'll learn to handle a rifle," said Lieutenant Mehra as she led the cadets to the shooting range. Raj's heart skipped a beat. He'd never even held a gun before.
The instructor handed him a .22 rifle and explained the basic rules: respect the weapon, keep your finger off the trigger until you're ready, and always aim carefully. Raj took a deep breath, placed the rifle against his shoulder, and peered through the sights. His hands were trembling, but he squeezed the trigger. Bang!
His shot missed completely. He felt embarrassed but refused to give up.
The days passed, and with each practice, Raj's aim improved. He learned the importance of patience and control. The rifle wasn't just about firing; it was about focusing his mind, breathing steady, and staying calm.
On the last day of camp, there was a shooting competition. Raj wasn't expecting to win, but he focused on what he'd learned—discipline, patience, responsibility. One shot. Two shots. Both hit the target.
He didn't win the competition, but when Lieutenant Mehra smiled and nodded at him, he knew he had won something far more important: confidence, respect, and the understanding that true strength comes from control, not power.
'''
script2='''
Strengths of Agile Software Development
 Flexibility:
 1. Highly adaptable to evolving requirements, design changes, and scope modifications.
 2. Enables seamless integration of feedback and facilitates swift adjustments.
 1.Customer Involvement:
 1. Encourages frequent customer engagement, resulting in products closely aligned with user needs.
 2. Facilitates a collaborative environment, fostering open communication and mutual understanding.
 2.Continuous Delivery:
 1. Promotes regular, incremental releases of functional software, allowing for ongoing feedback and improvements.
 2. Ensures that working software is delivered to customers regularly, maintaining momentum.
 3.Collaboration:
 1. Emphasizes teamwork, fostering better communication, problem-solving, and idea exchange.
 2. Encourages a sense of shared ownership among team members, enhancing project cohesion.
 4.Early and Frequent Testing:
 1. Identifies issues and bugs early in the development process, enabling prompt resolution.
 2. Streamlines development by preventing the accumulation of unresolved problems.
'''

# %%
ad=generate_voice(script1,audio_path)
# Out:
#  > tts_models/en/ljspeech/tacotron2-DDC is already downloaded.
#  > vocoder_models/en/ljspeech/hifigan_v2 is already downloaded.
#  > Using model: Tacotron2
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:2.718281828459045
#  | > hop_length:256
#  | > win_length:1024
# ...
